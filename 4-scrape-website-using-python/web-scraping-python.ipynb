# %% [markdown]
# # Explore Web Scraping Method
#
# In this project, I explore 3 python packages which can be used for Website Scraping.

# %% [markdown]
# ### Method 1. Using Socket
#
# Socket is a low-level interface to pull information from website.

# %%
## This is a low-level to get file or image of the web server
import socket
mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('www.py4inf.com', 80))

# %%
mysock.send('GET http://www.py4inf.com/code/romeo.txt HTTP/1.0\n\n'.encode())
while True:
    data = mysock.recv(512)
    if (len(data) < 1) :
        break
    print (data)
mysock.close()
# Out:
# b'HTTP/1.1 404 Not Found\r\nServer: nginx\r\nDate: Thu, 09 Apr 2020 16:39:35 GMT\r\nContent-Type: text/html\r\nContent-Length: 146\r\nConnection: close\r\n\r\n<html>\r\n<head><title>404 Not Found</title></head>\r\n<body>\r\n<center><h1>404 Not Found</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %% [markdown]
# Note: encode() converts string to byte-like object; decode() converts byte-like object to string.

# %% [markdown]
# ### Method 2. Using urllib
# Using urllib, I can treat a web page much like a file. You simply indicate which web page you would like to retrieve and urllib handles all of the HTTP protocol and header details.

# %%
import urllib

# %%
fhand = urllib.request.urlopen('http://www.py4inf.com/code/romeo.txt')
for line in fhand:
    print (line.strip())
# Out:
# b'But soft what light through yonder window breaks'
# b'It is the east and Juliet is the sun'
# b'Arise fair sun and kill the envious moon'
# b'Who is already sick and pale with grief'

# %% [markdown]
# #### Parsing HTML using regular expressions
# One of the common uses of the urllib capability in Python is to scrape the web.
# Web scraping is when we write a program that pretends to be a web browser and
# retrieves pages, then examines the data in those pages looking for patterns.

# %%
import re
url = 'http://www.py4inf.com'
html = urllib.request.urlopen(url).read().decode('utf-8')
#Using .decode('utf-8') to convert the byte-like object obtained from the request to string
print (html)
links = re.findall('href="(http://.*?)"', html)
for link in links:
    print (link)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN"
#      "DTD/xhtml1-strict.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">
# <head>
# <title>PythonLearn - Exploring Data</title>
# <link rel="stylesheet" href="glike.css" type="text/css" />
# <link rel="alternate" type="application/rss+xml" title="PythonLearn Podcast"
# href="http://www.pythonlearn.com/audiofeed.xml" />
# </head>
# <body>
# <div id="header">
# <h1><a href="index.php" class="selected" accesskey="1">PythonLearn</a></h1>
# <ul class="toolbar">
# <li><a href="book.php" >Book</a></li>
# <li><a href="install.php" >Install</a></li>
# <li><a href=http://www.pr4e.org/ target="_blank">MOOC</a></li>
# <li><a href="http://www.dr-chuck.com/" target="_blank">Instructor</a></li>
# <li><a href="http://www.python.org/" target="_blank">Python</a></li>
# <li><a href="about.php" >About</a></li>
# </ul>
# </div>
# <div id="main">
# <div style="float: right; width:300px; padding: 5px;">
# <iframe width="300" height="169" src="//www.youtube.com/embed/UQVK-dsU7-Y" frameborder="0" allowfullscreen></iframe>
# </div>
#     <p><b>New:</b> The <a href="http://www.py4e.com/">Python 3 version</a> of the book and course material is available at <a href="http://www.py4e.com/">www.py4e.com</a>.  This site is maintained for those who want to continue to learn
# Python 2.
#     </p>
# <p>
# The goal of this site is to provide a set of materials in support of my
# <a href="book.php">Python for Informatics: Exploring Information</a> book
# to allow
# you to learn Python on your own.  This page serves as an outline
# of the materials to support the textbook.
# </p>
# You can download the exercises, audio,
# and video lectures to your local computer so you can play them locally.  This
# can be done with either a Right-Click or a Control-Click in most browsers.
# </p>
# <p>
# <ul>
# <li>
# Welcome Lecture -
# (<a href="https://www.youtube.com/watch?v=UQVK-dsU7-Y&index=2&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ"
#     target="_blank">YouTube</a>,
# <a href="https://itunes.apple.com/us/podcast/python-for-informaticss-official/id711095516?mt=2" target="_blank">Audio podcast for all lectures</a>)
# </li>
# <li>
# Get your copy of the <a href="book.php">Python for Informatics:
# Exploring Information</a>.
#
# <li>
# Install the appropriate version of Python and a text editor
# for your system following
# <a href=install.php>these instructions</a>.  </li>
#
# <li>
# Download <a href="code.zip" target="_blank">Sample code from the book</a>.</li>
#
# <li>Play with the <a href="pythonauto/index.php">Auto-grader</a> and write a "hello world" program.
#
# <li>
# The
# <a href="https://drive.google.com/folderview?id=0B7X1ycQalUnyWXg2MVhTbEZFT28&usp=sharing" target="_blank">course slides</a>
# have been converted to Google drive and are being translated into 30 languages.
# </li>
#
# <li>Chapter 1 - Why program?
# (<a href="youtube/Py4Inf-01-Intro.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-01-Intro.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-01-Intro.mp4" target="_blank">Video</a>)
#
# <li>Chapter 2 - Variables, expressions, and statements
# (<a href="youtube/Py4Inf-02-Expressions.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-02-Expressions.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-02-Expressions.mp4" target="_blank">Video</a>)
#
# <br/>&nbsp;&nbsp;&bull;&nbsp;Worked Exercise Screencasts:
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-02.mp4"
#     target="_blank">2.2</a>,
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-03.mp4"
#     target="_blank">2.3</a> (suggest download)
#
# <li>Chapter 3 - Conditional Execution
# (<a href="youtube/Py4Inf-03-Conditional.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-03-Conditional.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-03-Conditional.mp4" target="_blank">Video</a>)
#
# <br/>&nbsp;&nbsp;&bull;&nbsp;Worked Exercise Screencasts:
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-01.mp4"
#     target="_blank">3.1</a>,
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-02.mp4"
#     target="_blank">3.2</a> (suggest download)
#
#
# <li>Chapter 4 - Functions
# (<a href="youtube/Py4Inf-04-Functions.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-04-Functions.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-04-Functions.mp4" target="_blank">Video</a>)
#
# <br/>&nbsp;&nbsp;&bull;&nbsp;Worked Exercise Screencasts:
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-04-06.mp4"
#     target="_blank">4.6</a> (suggest download)
#
# <li>Chapter 5 - Loops and iterations
# (<a href="youtube/Py4Inf-05-Iterations.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-05-Iterations.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-05-Iterations.mp4" target="_blank">Video</a>)
#
# <br/>&nbsp;&nbsp;&bull;&nbsp;Worked Exercise Screencasts:
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-05-01.mp4"
#     target="_blank">5.1</a> (suggest download)
#
# <li>Chapter 6 - Strings
# (<a href="youtube/Py4Inf-06-Strings.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-06-Strings.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-06-Strings.mp4" target="_blank">Video</a>)
#
# <br/>&nbsp;&nbsp;&bull;&nbsp;Worked Exercise Screencasts:
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-06-07.mp4"
#     target="_blank">6.7</a> (suggest download)
#
# <li>Chapter 7 - Files
# (<a href="youtube/Py4Inf-07-Files.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-07-Files.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-07-Files.mp4" target="_blank">Video</a>)
#
# <br/>&nbsp;&nbsp;&bull;&nbsp;Worked Exercise Screencasts:
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-07-01.mp4"
#     target="_blank">7.1</a> (suggest download)
#
# <li>Chapter 8 - Lists
# (<a href="youtube/Py4Inf-08-Lists.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-08-Lists.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-08-Lists.mp4" target="_blank">Video</a>)
#
# <br/>&nbsp;&nbsp;&bull;&nbsp;Worked Exercise Screencasts:
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-08.mp4"
#     target="_blank">Finding and Fixing Errors - Lists of Words</a> (suggest download)
#
# <li>Chapter 9 - Dictionaries
# (<a href="youtube/Py4Inf-09-Dictionaries.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-09-Dictionaries.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-09-Dictionaries.mp4" target="_blank">Video</a>)
#
# <br/>&nbsp;&nbsp;&bull;&nbsp;Worked Exercise Screencasts:
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-09.mp4"
#     target="_blank">Most Common Word</a> (suggest download)
#
# <li>Chapter 10 - Tuples
# (<a href="youtube/Py4Inf-10-Tuples.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-10-Tuples.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-10-Tuples.mp4" target="_blank">Video</a>)
#
# <br/>&nbsp;&nbsp;&bull;&nbsp;Worked Exercise Screencasts:
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-10.mp4"
#     target="_blank">Top-5 Words</a> (suggest download)
# </li>
#
# <li>Chapter 11 - Regular Expressions
# (<a href="youtube/Py4Inf-11-Regex.php" target="_blank">YouTube</a>,
# <a href="podcasts/Py4Inf-11-Regex.mp3" target="_blank">Audio</a>,
# <a href="videos/Py4Inf-11-Regex.mp4" target="_blank">Video</a>,
# <a href="lectures/Py4Inf-11-Regex-Guide.pdf" target="_new">Regex-Guide</a>)
# </li>
#
# <li>
# When I teach from this book I spend two weeks on
# <a href="https://www.coursera.org/course/insidetheinternet" target="_blank">Internet
# History, Technology, and Security</a>
# between Chapters 11 and 12. Talking about history and technology allows the students
# to take a mental break from programming and lays the ground work for the
# second half of the book.
# </li>
#
# <li>Chapter 12 - Network Programming (HTTP)
# (<a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.ppt"
#     target="_blank">Slides</a>,
# <a href="https://www.youtube.com/watch?v=Zr8BQiPNaFI&index=30&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ"
#     target="_blank">YouTube</a>,
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.mov"
#     target="_blank">Download Video</a>,
# Lecture Audio
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-A.mp3"
#     target="_blank">Part 1</a> and
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-B.mp3"
#     target="_blank">Part 2</a>)
# <br/>&nbsp;&nbsp;&bull;&nbsp;Worked Exercise Screencasts:
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-12-04.mp4"
#     target="_blank">12.4 HTML Scraping with BeautifulSoup </a> (suggest download)
# </li>
# <li>Chapter 13 - Using Web Services
# (<a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-WebServices.ppt"
#     target="_blank">Slides</a>,
# <a href="https://www.youtube.com/watch?v=6cwi1NcL0Zc&index=31&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ"
#     target="_blank">YouTube</a>,
# Download Video
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-01.mp4"
#     target="_blank">Part 1</a>,
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-02.mp4"
#     target="_blank">Part 2</a>, and
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-03.mp4"
#     target="_blank">Part 3</a>)
# </li>
# <li>Chapter 14 - Databases
# (<a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database.ppt"
#     target="_blank">Slides</a>,
# Lecture Audio
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-A.mp3"
#     target="_blank">Part 1</a> and
# <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-B.mp3"
#     target="_blank">Part 2</a>)
# <br/>&nbsp;&nbsp;&bull;&nbsp;SQLite3 Browser: <a href="http://sqlitebrowser.org/" target="_blank">http://sqlitebrowser.org/</a>
# </li>
# </ul>
# <p>
# Here are <a href="videos/" target="_blank">archive copies</a> of the various audio, video, PowerPoints, PDFs and
# closed caption files if you want to reuse these materials in your own courses.
# All this material (including audio and video) is Copyright Creative Commons Attribution 3.0
# unless otherwise indicated.
# <p>
# Here are the materials for the
# <a href="workshop/materials.zip">Big Data Workshop</a>.
# </div>
# <script type="text/javascript">
# var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");
# document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
# </script>
# <script type="text/javascript">
# var pageTracker = _gat._getTracker("UA-423997-20");
# pageTracker._initData();
# pageTracker._trackPageview();
# </script>
# </body>
# </html>
#
# http://www.pythonlearn.com/audiofeed.xml
# http://www.dr-chuck.com/
# http://www.python.org/
# http://www.py4e.com/
# http://www.py4e.com/
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-02.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-03.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-01.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-02.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-04-06.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-05-01.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-06-07.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-07-01.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-08.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-09.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-10.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.ppt
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.mov
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-A.mp3
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-B.mp3
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-12-04.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-WebServices.ppt
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-01.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-02.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-03.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database.ppt
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-A.mp3
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-B.mp3
# http://sqlitebrowser.org/

# %% [markdown]
# #### Obtain binary file : pictures and video using urllib

# %%
## Deal with small size file
img = urllib.request.urlopen('http://www.py4inf.com/cover.jpg').read()
fhand = open('result/cover.jpg','wb')
fhand.write(img)
fhand.close()
##This program reads all of the data in at once across the network and stores it in the
#variable img in the main memory of your computer, then opens the file cover.jpg
#and writes the data out to your disk. This will work if the size of the file is less
#than the size of the memory of your computer.

# %% [markdown]
# However if this is a large audio or video file, this program may crash or at least
# run extremely slowly when your computer runs out of memory. In order to avoid
# running out of memory, we retrieve the data in blocks (or buffers) and then write
# each block to your disk before retrieving the next block. This way the program can
# read any size file without using up all of the memory you have in your computer.

# %%
img = urllib.request.urlopen('http://www.py4inf.com/cover.jpg')
fhand = open('result/cover1.jpg', 'wb')
size = 0
while True:
    info = img.read(100000) ## 100000 bytes is read in one time 
    if len(info) < 1 : break
    size = size + len(info)
    fhand.write(info)
print (size,'characters copied.')
fhand.close()
# Out:
# 70057 characters copied.

# %% [markdown]
# ### Method 3. Using Beatifulsoup
#
# Beatifulsoup is a handy to tool to scrape website.

# %%
import urllib
from bs4 import BeautifulSoup

# %%
url = 'http://www.py4inf.com'
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html)
# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    print (tag.get('href', None))
# Out:
# index.php
# book.php
# install.php
# http://www.pr4e.org/
# http://www.dr-chuck.com/
# http://www.python.org/
# about.php
# http://www.py4e.com/
# http://www.py4e.com/
# book.php
# https://www.youtube.com/watch?v=UQVK-dsU7-Y&index=2&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ
# https://itunes.apple.com/us/podcast/python-for-informaticss-official/id711095516?mt=2
# book.php
# install.php
# code.zip
# pythonauto/index.php
# https://drive.google.com/folderview?id=0B7X1ycQalUnyWXg2MVhTbEZFT28&usp=sharing
# youtube/Py4Inf-01-Intro.php
# podcasts/Py4Inf-01-Intro.mp3
# videos/Py4Inf-01-Intro.mp4
# youtube/Py4Inf-02-Expressions.php
# podcasts/Py4Inf-02-Expressions.mp3
# videos/Py4Inf-02-Expressions.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-02.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-03.mp4
# youtube/Py4Inf-03-Conditional.php
# podcasts/Py4Inf-03-Conditional.mp3
# videos/Py4Inf-03-Conditional.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-01.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-02.mp4
# youtube/Py4Inf-04-Functions.php
# podcasts/Py4Inf-04-Functions.mp3
# videos/Py4Inf-04-Functions.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-04-06.mp4
# youtube/Py4Inf-05-Iterations.php
# podcasts/Py4Inf-05-Iterations.mp3
# videos/Py4Inf-05-Iterations.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-05-01.mp4
# youtube/Py4Inf-06-Strings.php
# podcasts/Py4Inf-06-Strings.mp3
# videos/Py4Inf-06-Strings.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-06-07.mp4
# youtube/Py4Inf-07-Files.php
# podcasts/Py4Inf-07-Files.mp3
# videos/Py4Inf-07-Files.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-07-01.mp4
# youtube/Py4Inf-08-Lists.php
# podcasts/Py4Inf-08-Lists.mp3
# videos/Py4Inf-08-Lists.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-08.mp4
# youtube/Py4Inf-09-Dictionaries.php
# podcasts/Py4Inf-09-Dictionaries.mp3
# videos/Py4Inf-09-Dictionaries.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-09.mp4
# youtube/Py4Inf-10-Tuples.php
# podcasts/Py4Inf-10-Tuples.mp3
# videos/Py4Inf-10-Tuples.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-10.mp4
# youtube/Py4Inf-11-Regex.php
# podcasts/Py4Inf-11-Regex.mp3
# videos/Py4Inf-11-Regex.mp4
# lectures/Py4Inf-11-Regex-Guide.pdf
# https://www.coursera.org/course/insidetheinternet
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.ppt
# https://www.youtube.com/watch?v=Zr8BQiPNaFI&index=30&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.mov
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-A.mp3
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-B.mp3
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-12-04.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-WebServices.ppt
# https://www.youtube.com/watch?v=6cwi1NcL0Zc&index=31&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-01.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-02.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-03.mp4
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database.ppt
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-A.mp3
# http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-B.mp3
# http://sqlitebrowser.org/
# videos/
# workshop/materials.zip

# %%
url = 'http://www.py4inf.com'
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html)
# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
# Look at the parts of a tag
    print ('TAG:',tag)
    print ('URL:',tag.get('href', None))
    print ('Content:',tag.contents[0])
    print ('Attrs:',tag.attrs)
# Out:
# TAG: <a accesskey="1" class="selected" href="index.php">PythonLearn</a>
# URL: index.php
# Content: PythonLearn
# Attrs: {'href': 'index.php', 'class': ['selected'], 'accesskey': ['1']}
# TAG: <a href="book.php">Book</a>
# URL: book.php
# Content: Book
# Attrs: {'href': 'book.php'}
# TAG: <a href="install.php">Install</a>
# URL: install.php
# Content: Install
# Attrs: {'href': 'install.php'}
# TAG: <a href="http://www.pr4e.org/" target="_blank">MOOC</a>
# URL: http://www.pr4e.org/
# Content: MOOC
# Attrs: {'href': 'http://www.pr4e.org/', 'target': '_blank'}
# TAG: <a href="http://www.dr-chuck.com/" target="_blank">Instructor</a>
# URL: http://www.dr-chuck.com/
# Content: Instructor
# Attrs: {'href': 'http://www.dr-chuck.com/', 'target': '_blank'}
# TAG: <a href="http://www.python.org/" target="_blank">Python</a>
# URL: http://www.python.org/
# Content: Python
# Attrs: {'href': 'http://www.python.org/', 'target': '_blank'}
# TAG: <a href="about.php">About</a>
# URL: about.php
# Content: About
# Attrs: {'href': 'about.php'}
# TAG: <a href="http://www.py4e.com/">Python 3 version</a>
# URL: http://www.py4e.com/
# Content: Python 3 version
# Attrs: {'href': 'http://www.py4e.com/'}
# TAG: <a href="http://www.py4e.com/">www.py4e.com</a>
# URL: http://www.py4e.com/
# Content: www.py4e.com
# Attrs: {'href': 'http://www.py4e.com/'}
# TAG: <a href="book.php">Python for Informatics: Exploring Information</a>
# URL: book.php
# Content: Python for Informatics: Exploring Information
# Attrs: {'href': 'book.php'}
# TAG: <a href="https://www.youtube.com/watch?v=UQVK-dsU7-Y&amp;index=2&amp;list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ" target="_blank">YouTube</a>
# URL: https://www.youtube.com/watch?v=UQVK-dsU7-Y&index=2&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ
# Content: YouTube
# Attrs: {'href': 'https://www.youtube.com/watch?v=UQVK-dsU7-Y&index=2&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ', 'target': '_blank'}
# TAG: <a href="https://itunes.apple.com/us/podcast/python-for-informaticss-official/id711095516?mt=2" target="_blank">Audio podcast for all lectures</a>
# URL: https://itunes.apple.com/us/podcast/python-for-informaticss-official/id711095516?mt=2
# Content: Audio podcast for all lectures
# Attrs: {'href': 'https://itunes.apple.com/us/podcast/python-for-informaticss-official/id711095516?mt=2', 'target': '_blank'}
# TAG: <a href="book.php">Python for Informatics:
# Exploring Information</a>
# URL: book.php
# Content: Python for Informatics:
# Exploring Information
# Attrs: {'href': 'book.php'}
# TAG: <a href="install.php">these instructions</a>
# URL: install.php
# Content: these instructions
# Attrs: {'href': 'install.php'}
# TAG: <a href="code.zip" target="_blank">Sample code from the book</a>
# URL: code.zip
# Content: Sample code from the book
# Attrs: {'href': 'code.zip', 'target': '_blank'}
# TAG: <a href="pythonauto/index.php">Auto-grader</a>
# URL: pythonauto/index.php
# Content: Auto-grader
# Attrs: {'href': 'pythonauto/index.php'}
# TAG: <a href="https://drive.google.com/folderview?id=0B7X1ycQalUnyWXg2MVhTbEZFT28&amp;usp=sharing" target="_blank">course slides</a>
# URL: https://drive.google.com/folderview?id=0B7X1ycQalUnyWXg2MVhTbEZFT28&usp=sharing
# Content: course slides
# Attrs: {'href': 'https://drive.google.com/folderview?id=0B7X1ycQalUnyWXg2MVhTbEZFT28&usp=sharing', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-01-Intro.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-01-Intro.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-01-Intro.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-01-Intro.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-01-Intro.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-01-Intro.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-01-Intro.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-01-Intro.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-01-Intro.mp4', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-02-Expressions.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-02-Expressions.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-02-Expressions.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-02-Expressions.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-02-Expressions.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-02-Expressions.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-02-Expressions.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-02-Expressions.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-02-Expressions.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-02.mp4" target="_blank">2.2</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-02.mp4
# Content: 2.2
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-02.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-03.mp4" target="_blank">2.3</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-03.mp4
# Content: 2.3
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-02-03.mp4', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-03-Conditional.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-03-Conditional.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-03-Conditional.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-03-Conditional.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-03-Conditional.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-03-Conditional.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-03-Conditional.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-03-Conditional.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-03-Conditional.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-01.mp4" target="_blank">3.1</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-01.mp4
# Content: 3.1
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-01.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-02.mp4" target="_blank">3.2</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-02.mp4
# Content: 3.2
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-03-02.mp4', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-04-Functions.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-04-Functions.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-04-Functions.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-04-Functions.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-04-Functions.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-04-Functions.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-04-Functions.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-04-Functions.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-04-Functions.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-04-06.mp4" target="_blank">4.6</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-04-06.mp4
# Content: 4.6
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-04-06.mp4', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-05-Iterations.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-05-Iterations.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-05-Iterations.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-05-Iterations.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-05-Iterations.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-05-Iterations.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-05-Iterations.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-05-Iterations.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-05-Iterations.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-05-01.mp4" target="_blank">5.1</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-05-01.mp4
# Content: 5.1
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-05-01.mp4', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-06-Strings.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-06-Strings.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-06-Strings.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-06-Strings.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-06-Strings.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-06-Strings.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-06-Strings.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-06-Strings.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-06-Strings.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-06-07.mp4" target="_blank">6.7</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-06-07.mp4
# Content: 6.7
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-06-07.mp4', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-07-Files.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-07-Files.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-07-Files.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-07-Files.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-07-Files.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-07-Files.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-07-Files.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-07-Files.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-07-Files.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-07-01.mp4" target="_blank">7.1</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-07-01.mp4
# Content: 7.1
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-07-01.mp4', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-08-Lists.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-08-Lists.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-08-Lists.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-08-Lists.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-08-Lists.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-08-Lists.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-08-Lists.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-08-Lists.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-08-Lists.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-08.mp4" target="_blank">Finding and Fixing Errors - Lists of Words</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-08.mp4
# Content: Finding and Fixing Errors - Lists of Words
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-08.mp4', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-09-Dictionaries.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-09-Dictionaries.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-09-Dictionaries.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-09-Dictionaries.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-09-Dictionaries.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-09-Dictionaries.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-09-Dictionaries.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-09-Dictionaries.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-09-Dictionaries.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-09.mp4" target="_blank">Most Common Word</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-09.mp4
# Content: Most Common Word
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-09.mp4', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-10-Tuples.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-10-Tuples.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-10-Tuples.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-10-Tuples.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-10-Tuples.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-10-Tuples.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-10-Tuples.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-10-Tuples.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-10-Tuples.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-10.mp4" target="_blank">Top-5 Words</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-10.mp4
# Content: Top-5 Words
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/exercises/Py4Inf-ex-10.mp4', 'target': '_blank'}
# TAG: <a href="youtube/Py4Inf-11-Regex.php" target="_blank">YouTube</a>
# URL: youtube/Py4Inf-11-Regex.php
# Content: YouTube
# Attrs: {'href': 'youtube/Py4Inf-11-Regex.php', 'target': '_blank'}
# TAG: <a href="podcasts/Py4Inf-11-Regex.mp3" target="_blank">Audio</a>
# URL: podcasts/Py4Inf-11-Regex.mp3
# Content: Audio
# Attrs: {'href': 'podcasts/Py4Inf-11-Regex.mp3', 'target': '_blank'}
# TAG: <a href="videos/Py4Inf-11-Regex.mp4" target="_blank">Video</a>
# URL: videos/Py4Inf-11-Regex.mp4
# Content: Video
# Attrs: {'href': 'videos/Py4Inf-11-Regex.mp4', 'target': '_blank'}
# TAG: <a href="lectures/Py4Inf-11-Regex-Guide.pdf" target="_new">Regex-Guide</a>
# URL: lectures/Py4Inf-11-Regex-Guide.pdf
# Content: Regex-Guide
# Attrs: {'href': 'lectures/Py4Inf-11-Regex-Guide.pdf', 'target': '_new'}
# TAG: <a href="https://www.coursera.org/course/insidetheinternet" target="_blank">Internet
# History, Technology, and Security</a>
# URL: https://www.coursera.org/course/insidetheinternet
# Content: Internet
# History, Technology, and Security
# Attrs: {'href': 'https://www.coursera.org/course/insidetheinternet', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.ppt" target="_blank">Slides</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.ppt
# Content: Slides
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.ppt', 'target': '_blank'}
# TAG: <a href="https://www.youtube.com/watch?v=Zr8BQiPNaFI&amp;index=30&amp;list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ" target="_blank">YouTube</a>
# URL: https://www.youtube.com/watch?v=Zr8BQiPNaFI&index=30&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ
# Content: YouTube
# Attrs: {'href': 'https://www.youtube.com/watch?v=Zr8BQiPNaFI&index=30&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.mov" target="_blank">Download Video</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.mov
# Content: Download Video
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-HTTP.mov', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-A.mp3" target="_blank">Part 1</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-A.mp3
# Content: Part 1
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-A.mp3', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-B.mp3" target="_blank">Part 2</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-B.mp3
# Content: Part 2
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-12-Net-Prog-B.mp3', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-12-04.mp4" target="_blank">12.4 HTML Scraping with BeautifulSoup </a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-12-04.mp4
# Content: 12.4 HTML Scraping with BeautifulSoup
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-ex-12-04.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-WebServices.ppt" target="_blank">Slides</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-WebServices.ppt
# Content: Slides
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-WebServices.ppt', 'target': '_blank'}
# TAG: <a href="https://www.youtube.com/watch?v=6cwi1NcL0Zc&amp;index=31&amp;list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ" target="_blank">YouTube</a>
# URL: https://www.youtube.com/watch?v=6cwi1NcL0Zc&index=31&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ
# Content: YouTube
# Attrs: {'href': 'https://www.youtube.com/watch?v=6cwi1NcL0Zc&index=31&list=PLlRFEj9H3Oj4JXIwMwN1_ss1Tk8wZShEJ', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-01.mp4" target="_blank">Part 1</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-01.mp4
# Content: Part 1
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-01.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-02.mp4" target="_blank">Part 2</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-02.mp4
# Content: Part 2
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-02.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-03.mp4" target="_blank">Part 3</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-03.mp4
# Content: Part 3
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-13-Webservices-03.mp4', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database.ppt" target="_blank">Slides</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database.ppt
# Content: Slides
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database.ppt', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-A.mp3" target="_blank">Part 1</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-A.mp3
# Content: Part 1
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-A.mp3', 'target': '_blank'}
# TAG: <a href="http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-B.mp3" target="_blank">Part 2</a>
# URL: http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-B.mp3
# Content: Part 2
# Attrs: {'href': 'http://www-personal.umich.edu/~csev/books/py4inf/media/Py4Inf-14-Database-B.mp3', 'target': '_blank'}
# TAG: <a href="http://sqlitebrowser.org/" target="_blank">http://sqlitebrowser.org/</a>
# URL: http://sqlitebrowser.org/
# Content: http://sqlitebrowser.org/
# Attrs: {'href': 'http://sqlitebrowser.org/', 'target': '_blank'}
# TAG: <a href="videos/" target="_blank">archive copies</a>
# URL: videos/
# Content: archive copies
# Attrs: {'href': 'videos/', 'target': '_blank'}
# TAG: <a href="workshop/materials.zip">Big Data Workshop</a>
# URL: workshop/materials.zip
# Content: Big Data Workshop
# Attrs: {'href': 'workshop/materials.zip'}
